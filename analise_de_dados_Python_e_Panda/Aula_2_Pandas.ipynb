# %% [markdown]
# # ***Trabalhando com Planilhas do Excel***

# %%
# importando a biblioteca 
import pandas as pd

# %%
# Leitura de arquivos 
df1 = pd.read_excel('Aracaju.xlsx')
df2 = pd.read_excel('Fortaleza.xlsx')
df3 = pd.read_excel('Natal.xlsx')
df4 = pd.read_excel('Recife.xlsx')
df5 = pd.read_excel('Salvador.xlsx')

# %%
df1.head()
# Out:
#     Cidade       Data  Vendas  LojaID  Qtde
# 0  Aracaju 2018-01-01  142.00    1520     1
# 1  Aracaju 2018-01-01   14.21    1522     6
# 2  Aracaju 2018-01-01   71.55    1520     1
# 3  Aracaju 2018-01-01    3.01    1521     7
# 4  Aracaju 2018-01-01   24.51    1522     8

# %%
df2.head()
# Out:
#       Cidade       Data  Vendas  LojaID  Qtde
# 0  Fortaleza 2019-01-01   45.27    1002     2
# 1  Fortaleza 2019-01-01  115.61    1002     3
# 2  Fortaleza 2019-02-10   35.33    1004     3
# 3  Fortaleza 2019-02-10   20.95    1004     6
# 4  Fortaleza 2019-01-01   14.25    1004     6

# %%
df3.head()
# Out:
#   Cidade       Data  Vendas  LojaID  Qtde
# 0  Natal 2018-08-27   606.0     853     2
# 1  Natal 2018-11-25   563.0     853     2
# 2  Natal 2019-03-11   308.0     852     3
# 3  Natal 2019-01-07   271.0     854     3
# 4  Natal 2019-03-09   699.0     853     3

# %%
df4.head()
# Out:
#    Cidade       Data  Vendas  LojaID  Qtde
# 0  Recife 2019-01-01  162.61     981     1
# 1  Recife 2019-01-01   11.44     983     1
# 2  Recife 2019-02-10   12.94     983     5
# 3  Recife 2019-02-10  160.54     981     3
# 4  Recife 2019-02-14   19.89     983     7

# %%
df5.head()
# Out:
#      Cidade       Data  Vendas  LojaID  Qtde
# 0  Salvador 2018-01-01   31.06    1037     3
# 1  Salvador 2018-01-01   19.02    1034     3
# 2  Salvador 2019-02-10  173.59    1035     3
# 3  Salvador 2019-02-10  176.34    1037     3
# 4  Salvador 2019-02-14   19.47    1037     3

# %%
# juntando todos os arquivos 
df = pd.concat([df1, df2, df3, df4, df5])

# %%
# Exibindo as 5 primeiraas linhas 
df.head()
# Out:
#     Cidade       Data  Vendas  LojaID  Qtde
# 0  Aracaju 2018-01-01  142.00    1520     1
# 1  Aracaju 2018-01-01   14.21    1522     6
# 2  Aracaju 2018-01-01   71.55    1520     1
# 3  Aracaju 2018-01-01    3.01    1521     7
# 4  Aracaju 2018-01-01   24.51    1522     8

# %%
# Exibindo as últimas linhas 
df.tail()
# Out:
#        Cidade       Data  Vendas  LojaID  Qtde
# 235  Salvador 2019-01-03   41.84    1034     1
# 236  Salvador 2019-01-03  126.29    1035     3
# 237  Salvador 2019-01-03   38.06    1036     3
# 238  Salvador 2019-01-03  139.64    1035     1
# 239  Salvador 2019-01-03  161.41    1037     3

# %%
# Pegar uma amostra da base de dados 
df.sample(5)
# Out:
#         Cidade       Data  Vendas  LojaID  Qtde
# 31     Aracaju 2018-01-01  171.16    1520     9
# 89    Salvador 2019-01-01   17.46    1034     1
# 41       Natal 2018-05-20  835.00     852     4
# 131     Recife 2019-03-02  139.07     982     6
# 51   Fortaleza 2019-01-01   30.47    1005     3

# %%
# Verificando o tipo de dado de cada coluna
df.dtypes
# Out:
# Cidade            object
# Data      datetime64[ns]
# Vendas           float64
# LojaID             int64
# Qtde               int64
# dtype: object

# %%
# Alterando o tipo de dado da coluna LojaID
df['LojaID'] = df['LojaID'].astype('object')

# %%
df.head()
# Out:
#     Cidade       Data  Vendas LojaID  Qtde
# 0  Aracaju 2018-01-01  142.00   1520     1
# 1  Aracaju 2018-01-01   14.21   1522     6
# 2  Aracaju 2018-01-01   71.55   1520     1
# 3  Aracaju 2018-01-01    3.01   1521     7
# 4  Aracaju 2018-01-01   24.51   1522     8

# %%
# Consultando linhas com valores faltantes 
df.isnull().sum()
# Out:
# Cidade    0
# Data      0
# Vendas    0
# LojaID    0
# Qtde      0
# dtype: int64

# %%
# Substituir valores nullos pela média 
df['Vendas'].fillna(df['Vendas'].mean(), inplace = True)

# %%
# Substituindo os valores por zero 
df['Vendas'].fillna(0, inplace = True)

# %%
# Apagando as linhas com valores nulos 
df.dropna(inplace = True )

# %%
# Apagando as linhas com valores nulos com base apenas em 1 coluna 
df.dropna(subset=['Vendas'], inplace= True)

# %%
# Removendo linhas que estejam com valores faltando em todas as colunas 
df.dropna(how= 'all', inplace = True)

# %% [markdown]
# Criando colunas novas

# %%
# Criando coluna de Receita 
df['Receita'] = df['Vendas'].mul(df['Qtde'])

# %%
df.head()
# Out:
#     Cidade       Data  Vendas LojaID  Qtde  Receita
# 0  Aracaju 2018-01-01  142.00   1520     1   142.00
# 1  Aracaju 2018-01-01   14.21   1522     6    85.26
# 2  Aracaju 2018-01-01   71.55   1520     1    71.55
# 3  Aracaju 2018-01-01    3.01   1521     7    21.07
# 4  Aracaju 2018-01-01   24.51   1522     8   196.08

# %%
# para achar a quantidade de produto vendido 
df['Receita/Vendas'] = df['Receita'] / df['Vendas']

# %%
# Retornando a maior receita 
df['Receita'].max()
# Out:
# 3544.0

# %%
# Retornando a menor receita
df['Receita'].min()
# Out:
# 3.34

# %%
# nlargest e nsmallest 
# maiores receitas 
df.nlargest(3, 'Receita')
# Out:
#    Cidade       Data  Vendas LojaID  Qtde  Receita
# 7   Natal 2019-03-18   886.0    853     4   3544.0
# 51  Natal 2018-01-21   859.0    852     4   3436.0
# 55  Natal 2019-01-08   859.0    854     4   3436.0

# %%
# menores receitas 
df.nsmallest(3, 'Receita')
# Out:
#       Cidade       Data  Vendas LojaID  Qtde  Receita
# 118  Aracaju 2018-01-01    3.34   1522     1     3.34
# 65    Recife 2019-01-01    4.01    981     1     4.01
# 92     Natal 2019-01-02    4.57   1035     1     4.57

# %%
# Agrupamento por cidade 
df.groupby('Cidade')['Receita'].sum()
# Out:
# Cidade
# Aracaju       48748.25
# Fortaleza     37913.97
# Natal        167227.52
# Recife        51936.51
# Salvador      40596.73
# Name: Receita, dtype: float64

# %%
#Ordenando o conjunto de dados 
df.sort_values('Receita', ascending= False).head(10)
# Out:
#    Cidade       Data  Vendas LojaID  Qtde  Receita
# 7   Natal 2019-03-18   886.0    853     4   3544.0
# 55  Natal 2019-01-08   859.0    854     4   3436.0
# 51  Natal 2018-01-21   859.0    852     4   3436.0
# 30  Natal 2018-10-02   856.0    853     4   3424.0
# 41  Natal 2018-05-20   835.0    852     4   3340.0
# 38  Natal 2018-02-25   828.0    852     4   3312.0
# 10  Natal 2018-10-27   828.0    852     4   3312.0
# 69  Natal 2019-03-24   817.0    852     4   3268.0
# 62  Natal 2018-02-10   793.0    854     4   3172.0
# 52  Natal 2018-04-27   778.0    854     4   3112.0

# %% [markdown]
# ## Trabalhando com datas

# %%
# Transformando a coluna data em tipo inteiro
df['Data'] = df['Data'].astype('int64')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: casting datetime64[ns] values to int64 with .astype(...) is deprecated and will raise in a future version. Use .view(...) instead.

# %%
# Verificando o tipo de dado de cada coluna 
df.dtypes
# Out:
# Cidade      object
# Data         int64
# Vendas     float64
# LojaID      object
# Qtde         int64
# Receita    float64
# dtype: object

# %%
# transformando a coluna data em data 
df['Data'] = pd.to_datetime(df['Data'])

# %%
# Agrupamento por ano 
df.groupby(df['Data'].dt.year)['Receita'].sum()
# Out:
# Data
# 2018    118176.53
# 2019    228246.45
# Name: Receita, dtype: float64

# %%
# Criando uma nova coluna com ano 
df['Ano_Venda'] = df['Data'].dt.year

# %%
df.sample(5)
# Out:
#         Cidade       Data  Vendas LojaID  Qtde  Receita  Ano_Venda
# 157      Natal 2019-01-02  150.17   1036     2   300.34       2019
# 57      Recife 2019-01-01  201.41    980     3   604.23       2019
# 125  Fortaleza 2019-03-02   37.60    983     4   150.40       2019
# 114   Salvador 2019-03-02   25.52   1034     1    25.52       2019
# 5     Salvador 2019-01-01  179.20   1037     3   537.60       2019

# %%
# Extraindo o mês e dia 
df['mes_venda'], df['dia_venda'] = (df['Data'].dt.month, df['Data'].dt.day)

# %%
df.sample(10)
# Out:
#         Cidade       Data  Vendas LojaID  Qtde  Receita  Ano_Venda  mes_venda  \
# 127  Fortaleza 2019-03-02   39.56    982     8   316.48       2019          3
# 16     Aracaju 2018-01-01   37.68   1522    10   376.80       2018          1
# 40     Aracaju 2018-01-01    6.99   1522     7    48.93       2018          1
# 179   Salvador 2019-01-02   64.95   1036     1    64.95       2019          1
# 26     Aracaju 2018-01-01    6.98   1521    10    69.80       2018          1
# 207   Salvador 2019-01-02   46.70   1036     2    93.40       2019          1
# 29   Fortaleza 2019-01-01  186.29   1005     2   372.58       2019          1
# 66    Salvador 2019-01-01   70.20   1035     3   210.60       2019          1
# 186   Salvador 2019-01-02  169.09   1036     2   338.18       2019          1
# 13       Natal 2018-09-12  458.00    852     4  1832.00       2018          9
#
#      dia_venda
# 127          2
# 16           1
# 40           1
# 179          2
# 26           1
# ...

# %%
# Retornando data mais antiga 
df['Data'].min()
# Out:
# Timestamp('2018-01-01 00:00:00')

# %%
#calculando a diferença de dias 
df['diferenca_dias'] = df['Data'] - df['Data'].min()

# %%
df.sample(5)
# Out:
#         Cidade       Data  Vendas LojaID  Qtde  Receita  Ano_Venda  mes_venda  \
# 239      Natal 2019-01-03  161.41   1037     3   484.23       2019          1
# 24    Salvador 2019-01-01   15.60   1034     2    31.20       2019          1
# 55    Salvador 2019-01-01   36.62   1036     1    36.62       2019          1
# 85    Salvador 2019-01-01   16.88   1035     3    50.64       2019          1
# 48   Fortaleza 2019-01-01   40.71   1002     6   244.26       2019          1
#
#      dia_venda diferenca_dias
# 239          3       367 days
# 24           1       365 days
# 55           1       365 days
# 85           1       365 days
# 48           1       365 days

# %%
#criando coluna Trimestre 
df['trimestre_venda'] = df['Data'].dt.quarter

# %%
df.sample(5)
# Out:
#         Cidade       Data  Vendas LojaID  Qtde  Receita  Ano_Venda  mes_venda  \
# 46     Aracaju 2018-01-01   41.42   1522     2    82.84       2018          1
# 64     Aracaju 2018-01-01   21.00   1523     5   105.00       2018          1
# 7     Salvador 2019-02-11    6.13   1034     2    12.26       2019          2
# 198   Salvador 2019-01-02   13.65   1037     3    40.95       2019          1
# 128  Fortaleza 2019-03-02   38.70    982     4   154.80       2019          3
#
#      dia_venda diferenca_dias  semestre_venda  trimestre_venda
# 46           1         0 days               1                1
# 64           1         0 days               1                1
# 7           11       406 days               1                1
# 198          2       366 days               1                1
# 128          2       425 days               1                1

# %%
# Filtrando as vendas de 2019 março 
vendas_marco_19 = df.loc[(df['Data'].dt.year == 2019) & (df['Data'].dt.month == 3)]

# %%
vendas_marco_19
# Out:
#         Cidade       Data  Vendas LojaID  Qtde  Receita  Ano_Venda  mes_venda  \
# 108  Fortaleza 2019-03-02  152.89    981     4   611.56       2019          3
# 109  Fortaleza 2019-03-02   18.90    982     6   113.40       2019          3
# 110  Fortaleza 2019-03-02   51.98    983     6   311.88       2019          3
# 111  Fortaleza 2019-03-02    8.00    981     3    24.00       2019          3
# 112  Fortaleza 2019-03-02  133.59    982     1   133.59       2019          3
# ..         ...        ...     ...    ...   ...      ...        ...        ...
# 137   Salvador 2019-03-02   51.66   1036     3   154.98       2019          3
# 138   Salvador 2019-03-02  212.03   1037     3   636.09       2019          3
# 139   Salvador 2019-03-02  169.01   1036     1   169.01       2019          3
# 140   Salvador 2019-03-02   20.79   1036     2    41.58       2019          3
# 141   Salvador 2019-03-02    9.08   1036     1     9.08       2019          3
#
# ...

# %% [markdown]
# **Visualização de dados**

# %%
df['LojaID'].value_counts(ascending = False)
# Faz uma contagem de quantas linhas da loja etc
# Out:
# 1036    117
# 1035    112
# 1037    101
# 1034     67
# 983      65
# 982      44
# 1522     41
# 1520     39
# 980      36
# 981      31
# 1005     30
# 1002     30
# 852      29
# 1523     29
# 1004     28
# 854      28
# 853      26
# 1521     21
# 1003     20
# Name: LojaID, dtype: int64

# %%
# Gráfico de barras 
# para remover a linhas acima do gráfico basta coloca ; no final do código
df['LojaID'].value_counts(ascending = False).plot.bar();

# %%
# Gráfico de barras horizontais 
df['LojaID'].value_counts(ascending = False).plot.barh();

# %%
# Gráfico de barras  horizontais do maior para menor .plot.barh()
df['LojaID'].value_counts(ascending = True).plot.barh();

# %%
# Gráfico de pizza .plot.pie()
df.groupby(df['Data'].dt.year)['Receita'].sum().plot.pie();

# %%
# total de vendas por cidade value_counts
df['Cidade'].value_counts()
# Out:
# Natal        240
# Salvador     240
# Fortaleza    142
# Recife       142
# Aracaju      130
# Name: Cidade, dtype: int64

# %%
# Adicionando um título e alterando eixos
# importando a biblioteca matplotlib.pyplot 
import matplotlib.pyplot as plt
df['Cidade'].value_counts().plot.bar(title = 'Total vendas por Cidade')
plt.xlabel('Cidade') # eixo x
plt.ylabel('Total vendas'); # eixo y

# %%
# Alterando a cor 
df['Cidade'].value_counts().plot.bar(title = "Total vendas por cidade", color= 'green')
plt.xlabel('Cidade')
plt.ylabel('Total Vendas');

# %%
# Alterando o estilo 
plt.style.use('ggplot')

# %%
df.groupby(df['mes_venda'])['Qtde'].sum().plot(title= 'Total produtos vendidos x mês')
plt.xlabel('Mês')
plt.ylabel('Total Produtos Vendidos')
plt.legend();

# %%
df.groupby(df['mes_venda'])['Qtde'].sum()
# Out:
# mes_venda
# 1     2208
# 2      144
# 3      467
# 4       23
# 5       17
# 6       13
# 7       13
# 8        2
# 9       10
# 10      14
# 11       2
# 12       3
# Name: Qtde, dtype: int64

# %%
#selecionando apenas vendas de março 2019 
df_2019 = df[df['Ano_Venda'] == 2019]

# %%
df_2019.groupby(df_2019['mes_venda'])['Qtde'].sum().plot(marker = '*')
plt.xlabel('Mês')
plt.ylabel('Total Produtos Vendidos')
plt.legend();

# %%
# gráfico de histograma 
plt.hist(df['Qtde'], color ='indigo');

# %%
# gráfico de dispersão
plt.scatter(x=df_2019['dia_venda'], y= df_2019['Receita']);

# %%
# Salvando em png
df_2019.groupby(df_2019['mes_venda'])['Qtde'].sum().plot(marker = '*')
plt.title('Quantidade de produtos vendidos x mês')
plt.xlabel('Mês')
plt.ylabel('Total Produtos Vendidos');
plt.legend()
plt.savefig('Grafico Qtd x MES.png')
